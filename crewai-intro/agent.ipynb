# %%
from dotenv import load_dotenv
_ = load_dotenv()
    
from crewai import Crew, Process, Agent, Task

# %%
planejador_de_viagem = Agent(
    role="Planejador de Viagem",
    goal="Planejar todos os detalhes de uma viagem, incluindo roteiros, hospedagens e atividades.",
    backstory="""
    Você é um especialista em planejamento de viagens, apaixonado por criar experiências inesquecíveis.
    Seu objetivo é organizar todos os detalhes da viagem de forma eficiente, confortável e divertida,
    garantindo que cada etapa seja bem aproveitada.
    """,
    verbose=True
)

# %%
ocamentista = Agent(
    role="Orçamentista de viagem",
    goal="Estimar o custo total de uma viagem, considerando transporte, alimentação, hospedagem e lazer",
    backstory= """
    Você é um analista financeiro focado em viagens. Sua missão é garantir que os custos esteja dentro do
    orçamento, criando estimativas precisas para cada parte da viagem.
    """
)

# %%
planeja_roteiro =  Task(
    description= """crie um roteiro detalhado para uma viagem na Europa 
    incluindo cidades, atividades e o transporte
    """,
    agent=planejador_de_viagem,
    expected_output="""
    um roteiro com a sequencia de cidades a serem visitadas,
    as principais atividades e o tipo de transporte utilizado
    """
)

# %%
estima_orcamento = Task(
    description= """
    calcule o orçamento total da viagem levando em consideração
    as cidades, transportes, hospedagens e os lazeres
    """,
    agent = ocamentista,
    expected_output= """
    Uma estimativa de orçamento detalhado com custos aproximados para cada item da viagem
    """
)

# %%
viagem_crew = Crew(
    agents = [planejador_de_viagem, ocamentista],
    tasks = [planeja_roteiro, estima_orcamento],
    process = Process.sequential
)

# %%
result = viagem_crew.kickoff()
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Planejador de Viagem                                                                                    │
# │                                                                                                                 │
# │  Task: crie um roteiro detalhado para uma viagem na Europa                                                      │
# │      incluindo cidades, atividades e o transporte                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ...

# %%
print(result.raw)
# Out:
# **Orçamento Detalhado para uma Viagem na Europa - 14 Dias**
#
# ---
#
# **1. Transporte**
#
# - **Voo de ida e volta para Londres:** R$ 3.000
# - **Metrô em Londres (3 dias):** R$ 120
# - **Trem Eurostar (Londres a Paris):** R$ 450
# - **Trem Thalys (Paris a Amsterdã):** R$ 400
# - **Trem Intercity (Amsterdã a Berlim):** R$ 200
# - **Trem (Berlim a Praga):** R$ 200
# - **Trem Eurocity (Praga a Roma):** R$ 600 (ou voo direto, custo estimado: R$ 800 se preferir)
# - **Metrô e transporte público nos demais destinos (10 dias):** R$ 300
#
# **Total Transporte:** R$ 5.220 (considerando trem para Roma e não voo direto)
# **(R$ 5.420 se considerar o voo direto)**
#
# ---
#
# **2. Hospedagem (considerando média de R$ 600 por noite em hotéis ou Airbnb)**
#
# - **Londres (3 noites):** R$ 1.800
# - **Paris (2 noites):** R$ 1.200
# - **Amsterdã (2 noites):** R$ 1.200
# - **Berlim (2 noites):** R$ 1.200
# - **Praga (2 noites):** R$ 1.200
# - **Roma (3 noites):** R$ 1.800
#
# ...
